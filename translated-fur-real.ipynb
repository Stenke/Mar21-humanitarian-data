# %%
# import libraries
import googletrans
from googletrans import Translator
import pandas as pd

# %%
# load data into a pandas data frame
df_es = pd.read_csv('round3_s04_acces_covid.csv')

# print first rows of the data frame
df_es.head()
# Out:
#     hhid region         s04q01a s04q02a s04q02a_autre         s04q01b s04q02b  \
# 0  20001  Kayes             OUI     NaN           NaN             OUI     NaN
# 1  20002  Kayes  N'A PAS ESSAYÉ     NaN           NaN             OUI     NaN
# 2  20005  Kayes  N'A PAS ESSAYÉ     NaN           NaN  N'A PAS ESSAYÉ     NaN
# 3  20006  Kayes  N'A PAS ESSAYÉ     NaN           NaN  N'A PAS ESSAYÉ     NaN
# 4  20007  Kayes             OUI     NaN           NaN             OUI     NaN
#
#   s04q02b_autre         s04q01c s04q02c  ... s04q11b__2 s04q11b__3 s04q11b__4  \
# 0           NaN             OUI     NaN  ...        NaN        NaN        NaN
# 1           NaN             OUI     NaN  ...        NaN        NaN        NaN
# 2           NaN  N'A PAS ESSAYÉ     NaN  ...        0.0        0.0        0.0
# 3           NaN  N'A PAS ESSAYÉ     NaN  ...        NaN        NaN        NaN
# 4           NaN  N'A PAS ESSAYÉ     NaN  ...        0.0        1.0        0.0
#
# ...

# %% [markdown]
# # Relevant Questions & Answers

# %% [markdown]
# Look for the most relevant QAs for Covid-related insecurities. Since region is attached, we can hopefully map this back to the specific regions to see which are hardest hit by food insecurities and loss of work.

# %%
df_employment = pd.read_csv('round1_s05_emploi_revenu_covid_as.csv')

# %%
df_employment['s05q05'].value_counts()
# Out:
# Pour votre propre compte                                          647
# En tant que salarié                                               248
# Dans une entreprise familiale ou gérée par un membre du ménage     57
# Dans une exploitation agricole familiale ou dans l'élevage         31
# En tant qu'apprenti, stagiaire                                     14
# Name: s05q05, dtype: int64

# %%
df_employment['s05q03'].value_counts()
# Out:
# COVID-19                                               179
# AUTRE, SPECIFIER                                        73
# TRAVAIL SAISONNIER                                      72
# ACTIVITE A l'ARRET(ENTREPRISE ou ADMINISTRATION)        36
# ABSENT TEMPORAIREMENT                                   19
# MALADIE                                                 12
# RETRAITE                                                 9
# REDUCTION DU PERSONNEL A CAUSE DU MANQUE D'ACTIVITE      3
# EN CHARGE DE PROCHES MALADES                             3
# Name: s05q03, dtype: int64

# %% [markdown]
# Above we can see that 406 of 1766 respondents lost work with 44.1% having lost jobs due to Covid itself. The next most are other and travel season (which one wonders is connected with Covid).
#
# Note: These were all free response (options were not read)

# %%
df_employment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1766 entries, 0 to 1765
# Data columns (total 96 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   hhid               1766 non-null   int64
#  1   region             1766 non-null   object
#  2   langue             1766 non-null   object
#  3   s05q01             1766 non-null   object
#  4   s05q02             769 non-null    object
#  5   s05q03             406 non-null    object
#  6   s05q03_autre       73 non-null     object
#  7   s05q04             406 non-null    object
#  8   s05q04_autre       41 non-null     object
#  9   s05q05             997 non-null    object
#  10  s05q06             262 non-null    object
#  11  s05q07             28 non-null     object
#  12  s05q07a            28 non-null     object
#  13  s04q7a_autre       6 non-null      object
#  14  s05q08             1766 non-null   object
#  15  s05q08a            966 non-null    object
# ...

# %% [markdown]
# # Appendix

# %% [markdown]
# ## Translation

# %%
test = df_es['s04q01a'][1]
test
# Out:
# "N'A PAS ESSAYÉ"

# %%
from textblob import TextBlob as tb

# %%
print(tb(test).translate())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-95-0eaf8e893bc8> in <module>
# ----> 1 print(tb(test).translate())
#
# /opt/anaconda3/lib/python3.8/site-packages/textblob/blob.py in translate(self, from_lang, to)
#     544         :rtype: :class:`BaseBlob <BaseBlob>`
#     545         """
# --> 546         return self.__class__(self.translator.translate(self.raw,
#     547                               from_lang=from_lang, to_lang=to))
#     548
#
# /opt/anaconda3/lib/python3.8/site-packages/textblob/translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# ...

# %%
def translator(text):
    return str(tb(text).translate())

# %%
translator(test)
# Out:
# "DIDN'T TRY"

# %%
test2 = df_es['s04q01a'][1]
translator(test2)
# Out:
# "DIDN'T TRY"

# %%
df_en['s04q01b'].apply(translator)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-92-1ebbce01a017> in <module>
# ----> 1 df_en['s04q01b'].apply(translator)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4106             else:
#    4107                 values = self.astype(object)._values
# -> 4108                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4109
#    4110         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-76-0b0bac9afbf7> in translator(text)
#       1 def translator(text):
# ----> 2     return str(tb(text).translate())
#
# /opt/anaconda3/lib/python3.8/site-packages/textblob/blob.py in translate(self, from_lang, to)
#     544         :rtype: :class:`BaseBlob <BaseBlob>`
#     545         """
# ...

# %%
df_en['s04q01a'].value_counts()

# %%
df_en = df_es.copy()

# %%
df_en.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1901 entries, 0 to 1900
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   hhid               1901 non-null   int64
#  1   region             1901 non-null   object
#  2   s04q01a            1901 non-null   object
#  3   s04q02a            25 non-null     object
#  4   s04q02a_autre      14 non-null     object
#  5   s04q01b            1901 non-null   object
#  6   s04q02b            25 non-null     object
#  7   s04q02b_autre      16 non-null     object
#  8   s04q01c            1901 non-null   object
#  9   s04q02c            31 non-null     object
#  10  s04q02c_autre      21 non-null     object
#  11  s04q01d            1901 non-null   object
#  12  s04q02d            48 non-null     object
#  13  s04q02d_autre      35 non-null     object
#  14  s04q01e            1901 non-null   object
#  15  s04q02e            6 non-null      object
# ...

# %%
df_en['p0'].dtype
# Out:
# dtype('O')

# %%
translations = {}
for column in df_en[['p0', 's04q01c']]:
    
    # unique elements of the column
    unique_elements = df_en[column].unique()
    
    for element in unique_elements:
        # add translation to the dictionary
        translations[element] = translator.translate(element).text
        
print(translations)
# Out:
# {'Non Pauvres': 'Non Pauvres', 'Pauvres': 'Pauvres', 'OUI': 'OUI', "N'A PAS ESSAYÉ": "N'A PAS ESSAYÉ", 'NON': 'NON'}

# %%
# modify all the terms of the data frame by using the previously created dictionary
df_en[['s04q01a', 's04q11b__1']].replace(translations, inplace = True)

# check translation
df_en.head()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4521: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
#     hhid region         s04q01a s04q02a s04q02a_autre         s04q01b s04q02b  \
# 0  20001  Kayes             OUI     NaN           NaN             OUI     NaN
# 1  20002  Kayes  N'A PAS ESSAYÉ     NaN           NaN             OUI     NaN
# 2  20005  Kayes  N'A PAS ESSAYÉ     NaN           NaN  N'A PAS ESSAYÉ     NaN
# 3  20006  Kayes  N'A PAS ESSAYÉ     NaN           NaN  N'A PAS ESSAYÉ     NaN
# 4  20007  Kayes             OUI     NaN           NaN             OUI     NaN
#
#   s04q02b_autre         s04q01c s04q02c  ... s04q11b__2 s04q11b__3 s04q11b__4  \
# 0           NaN             OUI     NaN  ...        NaN        NaN        NaN
# ...

# %%
df_en.head()
# Out:
#     hhid region         s04q01a s04q02a s04q02a_autre         s04q01b s04q02b  \
# 0  20001  Kayes             OUI     NaN           NaN             OUI     NaN
# 1  20002  Kayes  N'A PAS ESSAYÉ     NaN           NaN             OUI     NaN
# 2  20005  Kayes  N'A PAS ESSAYÉ     NaN           NaN  N'A PAS ESSAYÉ     NaN
# 3  20006  Kayes  N'A PAS ESSAYÉ     NaN           NaN  N'A PAS ESSAYÉ     NaN
# 4  20007  Kayes             OUI     NaN           NaN             OUI     NaN
#
#   s04q02b_autre         s04q01c s04q02c  ... s04q11b__2 s04q11b__3 s04q11b__4  \
# 0           NaN             OUI     NaN  ...        NaN        NaN        NaN
# 1           NaN             OUI     NaN  ...        NaN        NaN        NaN
# 2           NaN  N'A PAS ESSAYÉ     NaN  ...        0.0        0.0        0.0
# 3           NaN  N'A PAS ESSAYÉ     NaN  ...        NaN        NaN        NaN
# 4           NaN  N'A PAS ESSAYÉ     NaN  ...        0.0        1.0        0.0
#
# ...
